# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah-albar007-wq/-/blob/main/%D8%A7%D9%84%D8%AA%D8%AF%D8%B1%D9%8A%D8%A8_%D8%A7%D9%84%D8%A8%D8%B1%D9%85%D8%AC%D9%8A_%D8%A7%D9%84%D9%8A%D9%88%D9%85%D9%8A_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# اهلا و سهلا بكم! ساقوم هنا بكتابة اكواد و برامج بسيطة مثل الطباعة و العمليات الحسابية و صناعة المتغيرات و تخزين القيم فيها و حتى تحديد نوع القيم المخزنة! لا انكر انني وقتها لم افهم بشكل كامل هذه الاكواد لكن لا باس , اعتقد مجرد كتابتها مرات كثيرة و محاولة فهمها سيجزي نفعا بمشيئة الله

# %%
print("hello world")
# Out:
# hello world

# %%
print("abdo abar")
print(" Pasta")
# Out:
# abdo abar
#  Pasta

# %%
print( 25 * 4 )
# Out:
# 100

# %%
tu = 21
all = 91.5
a = "abdullah abar"
print(type(tu))
print(type(all))
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print(" my name is", a,"i'm",stu,"years old","i like a number",all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3498/2623535930.py in <cell line: 0>()
# ----> 1 print(" my name is", a,"i'm",stu,"years old","i like a number",all)
#
# NameError: name 'stu' is not defined

# %%
store = 0
store +=55
store +125
store -=25
store /= 25

# %%
store
# Out:
# 1.2

# %%
s = "ahmed"
print(s[3])

# %%
name = "abdalluah"
age = 21


print( f"my name is {name}, I am {age} years old")

# %%
1000==100
200==200
# Out:
# True

# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah-albar007-wq/-/blob/main/%D8%AA%D8%AF%D8%B1%D9%8A%D8%A8%D8%A7%D8%AA_%D8%A8%D8%B1%D9%85%D8%AC%D9%8A%D8%A9_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### نقوم بالتدرب على كتابة اوامر الطباعة و المتغيرات

# %%
print ('heiio world!') # نقوم بطباعة النص التسلسلي
# Out:
# heiio world!

# %%
# نقوم بطباعة النصوص و الارقام  و الفواصل
print ('i good!')
print (24)
print (67 , 48)
print ('score:',33)
print (55 + 88)
print (88 + 5 * 8)
print ((36 + 32) * 7)
print ('i good and i lave you ')

 # التعلقيات التي تبدا في علامة المربع او الهاشتاق مجرد توضيحات للبرنامج او الكود لنفسك او زملاء العمل و هذا شيء لا تقراه بايثون و تتجاهله
# Out:
# i good!
# 24
# 67 48
# score: 33
# 143
# 128
# 476
# i good and i lave you

# %%
# المسافات البادئة مهمة في لغة بايثون حيث تعتبر من القواعد البرمجية و جزء منها
if True:
 print (' goooood')
print (' goooood')
print (' goooood')
# Out:
#  goooood
#  goooood
#  goooood

# %%
if True:
 print("Indented")
print("Also indented")
# Out:
# Indented
# Also indented

# %%
# الاخطاء في كتابة اكواد بايثون البرمجية امر طبيعي و الفعل الصحيح عند فعل الخطا قراة تعليمات بايثون حول الخطا لمعرفة سبب المشكلة
prinew ('red man')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2347/1857105451.py in <cell line: 0>()
#       1 # الاخطاء في كتابة اكواد بايثون البرمجية امر طبيعي و الفعل الصحيح عند فعل الخطا قراة تعليمات بايثون حول الخطا لمعرفة سبب المشكلة
# ----> 2 prinew ('red man')
#
# NameError: name 'prinew' is not defined

# %%
# لذلك علينا فهم الاسم الصحيح و تعديله print (' goooood') يقول بايثون يوجد خطا في اسم
print (' red man')
# Out:
#  red man

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
#   نطبع اسمنا و طعامنا المفضل في سطرين منفصلين لذلك سنعمل  فاصلة بعد النص المتسلسل ليربط العلاقة بالنص الجديد
print ('mane:', 'abdullah')
print ('Favorite food:', 'Shrimp pasta')
# Out:
# mane: abdullah
# Favorite food: Shrimp pasta

# %%
# ستقوم هنا بطباعة ناتج ضرب 25 *4 و سنرى بايثون يجري عملية الضرب
print ( 25 * 4)
# عند كتابة امر الطباعة و ادخال الارقام دون علامتي التنصيص سيتعامل معها بايثون كارقام و يجري عمليات الحساب حسب ما يكتبه المبرمج
# Out:
# 100

# %%
#  لا يعمل بسبب نقص علامة التنصيص فالقيمة الموجودة بين اسطر الطباعة قيمة نصية لذلك عليك وضع علامتي تنصيص بين القيمة ليحولها بايثون لنص تسلسلي اما لو اردت قيمة رقمية فعليك ازالت التنصيص بالكامل prnt("Hello) السطر البرمجي
print (' Hello')
print (26365647)
# Out:
#  Hello
# 26365647

# %%
#  print سنقوم هنا بطباعة جملة كاملة تتضمن اسمي و ارقاما و فواصل فيها عبر امر
print ('Hello!, my name is abdullah, and i will be 31 years old in 10 years.')
# Out:
# Hello!, my name is abdullah, and i will be 31 years old in 10 years.

# %%
# المتغيرات عبارة عن قيم تحمل اسما ما و تحتوي على قيم متغيرات محددة بداخلها مثل النصوص و الارقام العادية و العشرية و الصواب و الخطا و يمكن استدعاء القيم و طباعتها
x = 33 # قيمة متغير رقمية
a = 'abdullah' # قيمة متغير نصية
q = 12.33 # قيمة متغير عشرية
k = True # قيمة متغير الصواب و الخطا/ صواب
b = False # قيمة متغير الصواب و الخطا / خطا
m = -5

# %%
# نقوم هنا باستدعاء قيم المتغيرات عبر طباعة اسمها
print (x)
print (a)
print (q)
print (k)
print (b)
# Out:
# 33
# abdullah
# 12.33
# True
# False

# %%
#نقوم بطباعة نص تسلسلي عبر امر التنصيص و نقوم بوضع فاصلة بعد علامتي التنصيص لبناء علاقة مع قيمة المتغير و طباعته

print ('age man:', x)
# قاعدة عامة: لعدّ الأشیاء استخدم الأعداد الصحیحة، ولقیاسھا (كالمال والطول والوزن) استخدم الأعداد العشریة.
# Out:
# age man: 33

# %%
print (k)
print (b)
# خلف كواليس الحاسب تترجم الصواب برقم 1 في لغة الحاسب و تترجم خطا 0
# Out:
# True
# False

# %%
# في بايثون لا يتم البوح بنوع القيم في المتغيرات بشكل مباشر لذلك يمكننا استخدام دالة تخبرنا بنوع القيم المخزنة في المتغيرات او التي نكتبها مباشرة
#  type الدالة تسمى

 # نحدد نوع قيمة ما عبر الكتابة و طباعتها مباشرة

print (type(88)) #  تم تحديد قيمة رقمية مطبوعة صحيحة موجب
print (type(12.39)) # تم تحديد قيمة غشرية مطبوعة
print (type('good')) # تم تحديد قيمة نصية تسلسلية مطبوعة
print (type(True)) # تم تحديد قيمة صواب و خطا مطبوعة/ صواب
print (type(False)) # تم تحديد قيمة صواب و خطا مطبوعة / خطا
print (type(-5))  #  تم تحديد قيمة رقمية مطبوعة صحيحة سالب
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'int'>

# %%
# نقوم الان بتحديد نوع القيم في المتغيرات المسماة و نقوم بطباعتها
print (type(x)) # تم تحديد قيمة رقمية مطبوعة
print (type(a))  # تم تحديد قيمة نصية تسلسلية مطبوعة
print (type(q))  # تم تحديد قيمة غشرية مطبوعة
print (type(k)) # تم تحديد قيمة صواب و خطا مطبوعة/ صواب
print (type(b)) # تم تحديد قيمة صواب و خطا مطبوعة / خطا
print (type(m))  #  تم تحديد قيمة رقمية مطبوعة صحيحة سالب
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'int'>

# %%
# يمكنك استخدام اسم الانواع كدوال تغير نوع قيمة المتغير لكن يشترط كتابة النوع بشكل صحيح
v = 'ahmad' # متغير قيمته نص تسلسلي

# %%
print (v) # عند طباعة المتغير سيتم طباعة النص التسلسلي
# Out:
# ahmad

# %%
v = int (1111) # نقوم هنا بتغيير نوع المتغير من قيم تسلسلية نصية الى قيم رقمية صحيحة

# %%
print (v) # عند الطباعة سيتم تغيير القيم النصية الى رقمية
# Out:
# 1111

# %%
# عند المحاولة بتغيير نوع القيمة المخزنة في المتغير من قيم نصية الى قيمة نصية اخرى عبر دالة النوع الرقمي سيحدث خطا بطبيعة الحال !
v = int ('ahmd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2347/667031003.py in <cell line: 0>()
#       1 # عند المحاولة بتغيير نوع القيمة المخزنة في المتغير من قيم نصية الى قيمة نصية اخرى عبر دالة النوع الرقمي سيحدث خطا بطبيعة الحال !
# ----> 2 v = int ('ahmd')
#
# ValueError: invalid literal for int() with base 10: 'ahmd'

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %%
# نقوم بانشاء ثلاث متغيرات عن نفسي عدد صحيح و عشري و نص
o = 21
I = 167.4
J = 'i abdullah!'

# %%
# نقوم بطباعة جملة تستخدم عدة متغيرات مع ربط العلاقة بينهم بالفواصل
print ('hello! ', J , 'and i age ',o ,'and my height',I)
# Out:
# hello!  i abdullah! and i age  21 and my height 167.4

# %%
#نستخدم دالة تقوم بالتحقق من نوع كل متغير
print (type(o))
print (type(I))
print (type(J))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#التحدي المبكر اعتقد الناتج سيكون طباعة العددين فقط مع بعض كنص تسلسلي
print ('3' + '5')
# Out:
# 35

# %%
print (type(3+5))
print (type('3' + '5'))

# الاول سيكون ناتج 8 مع تحديد نوع القيمة كرقم
# الثاني سيتم دمج الرقمين كنص تسلسلي و طباعته مع تحديد نوعه كقيمة نصية
# حسنا يبدوا كانه حدد النوع بدون اضافات للاسف.......
# Out:
# <class 'int'>
# <class 'str'>
